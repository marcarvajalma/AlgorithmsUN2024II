# %% [markdown]
# <a href="https://colab.research.google.com/github/marcarvajalma/AlgorithmsUN2024II/blob/main/LAB_ATQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laboratorio Quantiacs
# ## Maria Paula Carvajal

# %% [markdown]
# ##Gráfica y Sharpe ratio

# %% [markdown]
# ##Compra y venta

# %% [markdown]
# ![Screenshot 2025-01-29 083225.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-01-29 083005.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-01-29 083054.png](data:image/png;base64,...)

# %% [markdown]
# ##Compra

# %% [markdown]
# ![Screenshot 2025-01-29 090704.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-01-29 090742.png](data:image/png;base64,...)

# %% [markdown]
# ## Bernoulli Naive Bayes
#
# Se eligió el modelo **Bernoulli Naive Bayes** porque funciona muy bien en problemas de clasificación, especialmente cuando se trata de datos discretos o que pueden representarse de forma binaria, como detectar si algo ocurre o no. Es un modelo sencillo pero efectivo, que además es rápido de entrenar, lo que lo hace ideal para manejar grandes volúmenes de datos. Esto lo convierte en una buena opción para predecir los movimientos del mercado de manera eficiente.

# %% [markdown]
# ![Screenshot 2025-02-10 095449.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-10 095602.png](data:image/png;base64,...)

# %% [markdown]
# https://www.geeksforgeeks.org/bernoulli-naive-bayes/

# %% [markdown]
# https://blog.demir.io/hands-on-numpyro-a-practitioners-guide-to-building-bernoulli-naive-bayes-with-confidence-abc94f11cf9a

# %% [markdown]
# ## Variables agregadas

# %% [markdown]
# El **On Balance Volume (OBV)** es un indicador que mide el flujo de volumen acumulado en relación con los cambios de precio, basándose en la idea de que los movimientos de volumen preceden a los de precio. Si el precio cierra más alto que el día anterior, el volumen se suma al OBV; si cierra más bajo, se descarta; y si no cambia, el OBV permanece igual. Un OBV creciente indica una tendencia alcista, mientras que un OBV decreciente sugiere una tendencia bajista. Además, si el precio sube pero el OBV no lo sigue, puede señalar que la tendencia está perdiendo fuerza y que una reversión podría estar cerca.
#
# También se eligió el indicador **VWMA (Volume Weighted Moving Average)**, el cual es un indicador que le da mayor importancia a los periodos con más volumen. Este enfoque es que no solo considera el precio, sino también la fuerza del mercado basada en el volumen, lo que puede ayudar a obtener una visión más clara de las tendencias al reflejar mejor la actividad de los participantes.

# %% [markdown]
# ![Screenshot 2025-02-10 095727.png](data:image/png;base64,...)

# %% [markdown]
# https://quantiacs.com/documentation/en/user_guide/technical_indicators.html
